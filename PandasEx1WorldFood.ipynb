# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd
food = pd.read_csv('en.openfoodfacts.org.products.tsv', sep='\t', low_memory=False)
# https://www.kite.com/python/answers/how-load-a-.tsv-file-into-pandas-dataframe
# NOTE: error on import unless add the low_memory=False
# or ignore warning/error

# %%
# read to local file for faster response
# first create a new CSV file in my current directory, and then I can read in my data 

food.to_csv('food_local.csv')
# comment out the code I was using to read in my data and write to a CSV file after I have my CSV file.

# %%
# df = pd.read_csv('your_data.csv', index_col=0)
foodl = pd.read_csv('food_local.csv', index_col=0, low_memory=False)

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
foodl.head(5)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1  0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2  0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3  0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4  0000000016094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
foodl.info()
# 356026 ?
# use food.shape()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356027 entries, 0 to 356026
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(107), object(56)
# memory usage: 445.5+ MB

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
foodl.info()
# columns: 163
# use food.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356027 entries, 0 to 356026
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(107), object(56)
# memory usage: 445.5+ MB

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
# https://www.geeksforgeeks.org/how-to-get-column-names-in-pandas-dataframe/
col_names = list(foodl.columns)
print(col_names)
# or food.columns
# Out:
# ['code', 'url', 'creator', 'created_t', 'created_datetime', 'last_modified_t', 'last_modified_datetime', 'product_name', 'generic_name', 'quantity', 'packaging', 'packaging_tags', 'brands', 'brands_tags', 'categories', 'categories_tags', 'categories_en', 'origins', 'origins_tags', 'manufacturing_places', 'manufacturing_places_tags', 'labels', 'labels_tags', 'labels_en', 'emb_codes', 'emb_codes_tags', 'first_packaging_code_geo', 'cities', 'cities_tags', 'purchase_places', 'stores', 'countries', 'countries_tags', 'countries_en', 'ingredients_text', 'allergens', 'allergens_en', 'traces', 'traces_tags', 'traces_en', 'serving_size', 'no_nutriments', 'additives_n', 'additives', 'additives_tags', 'additives_en', 'ingredients_from_palm_oil_n', 'ingredients_from_palm_oil', 'ingredients_from_palm_oil_tags', 'ingredients_that_may_be_from_palm_oil_n', 'ingredients_that_may_be_from_palm_oil', 'ingredients_that_may_be_from_palm_oil_tags', 'nutrition_grade_uk', 'nutrition_grade_fr', 'pnns_groups_1'
# ...

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
# index not inclusive so request 106 to get the one before that which would be 105?
col_names[106]
# solutions says correct answer is '-glucose_100g' which is col_names[104]
# this is getting exact number requested, but numbering starts at 0 so need 1 fewer to get requested column
col_names[104]

# or food.columns[104]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
# this works, but solution presentation is cleaner, check solutions
type(foodl['-glucose_100g'][1])

# or food.dtypes['-glucose_100g']
# Out:
# numpy.float64

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
# not sure what this question is asking, check solutions
foodl.head(21)

# correct is food.index
# Out:
#              code                                                url  \
# 0   0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1   0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2   0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3   0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4   0000000016094  http://world-en.openfoodfacts.org/product/0000...
# 5   0000000016100  http://world-en.openfoodfacts.org/product/0000...
# 6   0000000016117  http://world-en.openfoodfacts.org/product/0000...
# 7   0000000016124  http://world-en.openfoodfacts.org/product/0000...
# 8   0000000016193  http://world-en.openfoodfacts.org/product/0000...
# 9   0000000016513  http://world-en.openfoodfacts.org/product/0000...
# 10  0000000016612  http://world-en.openfoodfacts.org/product/0000...
# 11  0000000016650  http://world-en.openfoodfacts.org/product/0000...
# 12  0000000016872  http://world-en.openfoodfacts.org/product/0000...
# ...

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
# exobrain https://www.kdnuggets.com/2019/06/select-rows-columns-pandas.html
# get index location of product_name column
prod = foodl.columns.get_loc('product_name')
# use that index with row index 20 and iloc
# iloc is getting exact index requested, but number starts at 0 so need 1 fewer index # for 19th observation
foodl.iloc[18, prod]

# or food.values[18][7]
# Out:
# 'Lotus Organic Brown Jasmine Rice'
